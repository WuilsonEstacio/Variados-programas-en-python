# %% [markdown]
# <a href="https://colab.research.google.com/github/WuilsonEstacio/Variados-programas-en-python/blob/main/codigo_con_while_love.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Codigo preguntas con while 
respuesta = "si"
i=0
print('Te gustaria escuchar un Poema hoy, \n He preparado Poemas para ti para cuando ya no pueda estar contigo')
while respuesta =="si":
  i=int(input("Solo ingresa tu numero de la suerte de 1 a 100 = "))
  print(" Para ti:")
  print('_'*64)
  if i >= 30:
    print('''
    He buscado esa señal de tu mirada durante tanto tiempo en mi vida
    la he buscado en las ovejas, en los libros en los cristales,
    en el silencio del desierto, y he alli en tus ojos estaba
    el puro lenguaje del mundo sin explicaciones porque el universo
    no necesita explicaciones para continuar su camino
    todo lo que entendia es que estaba delante de la mujer mas bella
    de la mujer de mi vida y sin mas palabras
    esperaba que ella lo supiera tambien
    ''')
    break
  elif 20 <= i < 30:
    print(''' 
    Para todos los caminos Que caminaremos juntos, \n 
    Para todos los paisajes Que veremos juntos, \n
    Un corazon timido y emocionado con todas las preguntas y tambien las respuestas,
    En todos esos momentos Yo te amo.23
    ''')
    break
  elif 15 <= i < 20:
    print('''
    Porque ver por separada esta vida y la siguiente 
    si una depende de la anterior
    ''')
    break
  elif 10 < i < 15:
    print(''' Convertirse en loco cuando estas enamorado es prueba de que
              tu cerebro esta activo, no enloquecer cuando amas no es normal.             
               ''')
    break  
  elif i==10:
    print("I just want to hold and kiss you from here to eternity.")
    break
  elif i==9:
    print(" Do you know somethings, your name sounds beautiful when it is accompanied with mine.")
    break
  elif i==8:
    print(''' No ter Rindas por favor no cedas, aunque el frio queme
              Aunque el miedo muera, aunque el sol se ponga y se calle el viento,
              Aun ahy fuego en tu alma, aun hay vida en tus sueños
              Porque cada dia es un comienxo nuevo,
              Porque esta es la hora y el mejor momento,
              Porque no estas sola, Porque yo "Te quiero"              
               ''')
    break    
  elif  i==7:
    print(" Solo espero con ancias que el destino tenga ganas de juntarnos pronto")
    break
  elif i == 6:
    print(''' Se escribe te "Te Extraño" y se borra antes de enviarlo para no perder la dignidad ''')
    break
  elif 3<= i < 5:
    print('''
    Lo intente, pero uno no puede amar por los dos...
    Yo lo intente y, me rompio el corazon en tantos pedazos que 
    casi no pude encontrarlos para volver a amarme.
    :) ''')
    break
  elif  2 <= i <3:
    print(" Bueno espero tener mas suerte la proxima")
    break
  elif  1 <= i < 2:
    print(" Almenos no me odies")
    break
  elif  i < 1:
    print(" Si estas destinado a conocer a alguien lo haras en algun momento")
    break
  else:
    while respuesta =="no":
      print(''' Antes de los 20 años es demasiado pronto para cumplir tus sueños 
              pero es un gran momento para iniciar ese sueño''')
    break
# Out:
# Te gustaria escuchar un Poema hoy,
#  He preparado Poemas para ti para cuando ya no pueda estar contigo
# Solo ingresa tu numero de la suerte de 1 a 100 = 50
#  Para ti:
# ________________________________________________________________
#
#     He buscado esa señal de tu mirada durante tanto tiempo en mi vida
#     la he buscado en las ovejas, en los libros en los cristales,
#     en el silencio del desierto, y he alli en tus ojos estaba
#     el puro lenguaje del mundo sin explicaciones porque el universo
#     no necesita explicaciones para continuar su camino
#     todo lo que entendia es que estaba delante de la mujer mas bella
#     de la mujer de mi vida y sin mas palabras
#     esperaba que ella lo supiera tambien

# %%
print('Te gustaria escuchar un Poema hoy.')
answer = input().lower
if answer() == "si":
    print(' He preparado Poemas para ti para cuando ya no pueda estar contigo')
    print('='*64)
    while respuesta =="si":
      i=int(input("Solo ingresa tu numero de la suerte de 1 a 100 = "))
      print(" Para ti:")
      print('='*64)
      if i >= 30:
        print('''
              He buscado esa señal de tu mirada durante tanto tiempo en mi vida
              la he buscado en las ovejas, en los libros en los cristales,
              en el silencio del desierto, y he alli en tus ojos estaba
              el puro lenguaje del mundo sin explicaciones porque el universo
              no necesita explicaciones para continuar su camino
              todo lo que entendia es que estaba delante de la mujer mas bella
              de la mujer de mi vida y sin mas palabras
              esperaba que ella lo supiera tambien
               ''')
        break
      elif 25 <= i < 30:
        print(''' 
               Para todos los caminos Que caminaremos juntos,  
               Para todos los paisajes Que veremos juntos,
               Un corazon timido y emocionado con todas las preguntas y tambien las respuestas,
               En todos esos momentos Yo te amo
              ''')
        break
      elif 23 <= i < 25:
        print(''' 
               Me gustaria pensar que voy a verte. No sé en que lugar, ni en que estacion 
               o en que circunstancia. No se si hoy, mañana, en unos años o en alguna otra vida.
               No se si sioendo niños, jovenes o ancianos; en forma de persona, de agua y piedra,
               flor  y tierra o lluvia y cielo.
               Solo pernsar que voy a verte de algun modo; en algun tiempo en que nuestros destinos
               coincidan nuevamente. Solo pienso en eso.
               Me Gusta pensar que voy a verte
              ''')
        break
      elif 20 <= i < 23:
        print(''' 
               Perdon por quererete en tan poco tiempo,
               pero es que encajaste perfectamente
               con lo que nunca busque,
               pero siempre necesité
              ''')
        break
      elif 18 <= i < 20:
        print('''
             Que si, puede que estas loca. tienes mas manias de las que puedo contar con las manos
             Sin embargo hay algo en ti y en tu manera de abrazar mi locura que se asemeja
             al cielo trallendo paz a mi infierno.
            ''')
        break

      elif 15 <= i < 18:
        print('''
             Porque ver por separada esta vida y la siguiente 
            si una depende de la anterior
            ''')
        break
      elif 11 < i < 15:
        print(''' Convertirse en loco cuando estas enamorado es prueba de que
                  tu cerebro esta activo, no enloquecer cuando amas no es normal.             
               ''')
        break
      elif i==11:
        print(''' Eres tu mi secreto inconfesable, mi arrepentimiento imposible,
                  mi sueño inalcanzable y mi amor inolvidable.             
               ''')
        break            
      elif i==10:
        print("I just want to hold and kiss you from here to eternity.")
        break
      elif i==9:
       print(" Do you know somethings, your name sounds beautiful when it is accompanied with mine.")
       break
      elif i==8:
         print(''' No ter Rindas por favor no cedas, aunque el frio queme
                  Aunque el miedo muera, aunque el sol se ponga y se calle el viento,
                  Aun ahy fuego en tu alma, aun hay vida en tus sueños
                  Porque cada dia es un comienxo nuevo,
                  Porque esta es la hora y el mejor momento,
                  Porque no estas sola, Porque yo "Te quiero"              
               ''')
         break    
      elif  i==7:
        print(" Solo espero con ancias que el destino tenga ganas de juntarnos pronto")
        break
      elif i == 6:
        print(''' Se escribe "Te Extraño" y se borra antes de enviarlo para no perder la dignidad ''')
        break
      elif i ==5:
        print(''' Antes de los 20 años es demasiado pronto para cumplir tus sueños 
              pero es un gran momento para iniciar ese sueño :)''') 
        break
      elif i==4:
        print('''
            Lo intente, pero uno no puede amar por los dos...
            Yo lo intente y, me rompio el corazon en tantos pedazos que 
            casi no pude encontrarlos para volver a amarme.
            :) ''')
        break
      elif  i==3:
        print(''' se que hpy ha sido duro para ti pero recuerda que primero estoy contigo
                   y segundo que los dias malos solo duran 24 horas, asi que se fuerte y resiste. ''')
        break
      elif  i==2:
        print('''Ódiame o amame, ambas estan a mi favor.
                Si me amas, estare en tu corazón si me odias estare en tu mente.
                ''')
        break
      elif  i == 1:
        print(" Si estas destinado a conocer a alguien lo haras en algun momento")
        break
      else:
        print(''' Hay besos que pronuncuan por si solos la sentencia de amor condenatoria..
                  Hay besos que se dan con la mirada, 
                  Hay besos que se dan con la memoria.''')
        break
if answer() == "no":

    print("Vale que tengas un agradable dia y que pronto decidas regresar...")
# Out:
# Te gustaria escuchar un Poema hoy.
# si
#  He preparado Poemas para ti para cuando ya no pueda estar contigo
# ...
# Solo ingresa tu numero de la suerte de 1 a 100 = 25
#  Para ti:
# ...
#
#                Para todos los caminos Que caminaremos juntos,
#
#                Para todos los paisajes Que veremos juntos,
#
#                Un corazon timido y emocionado con todas las preguntas y tambien las respuestas,
#                En todos esos momentos Yo te amo.23

# %%
# sigue intentando
import numpy as np
import matplotlib.pyplot as plt
import PIL
from skimage import io


image=io.imread("np.png") # imread lee las imagenes con los pixeles codificados como enteros 
# en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1

print("- Dimensiones de la imagen:")
print(image.shape)
plt.imshow(image,vmin=0,vmax=1)

# %%
# sigue intentando
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from PIL import Image

imagen = Image.open("np.jpg")
imagen.show()

# %%
file=open("newfile.txt","r")
print("reading initial contents")
print(file.read())
print("finished")
file.close()

file=open("newfile.txt", "w")
file.write("some new text")
file.close()

file= open("newfile.txt","r")
print("reading new contents")
print(file.read())
print("Finished")
file.close
# Out:
# reading initial contents
# some new text
# finished
# reading new contents
# some new text
# Finished
# <function TextIOWrapper.close>
